# %% [markdown]
# ## IGM tests
#
# Here we look at:
# 1. The effect of widening IGM priors
# 2. Running a chain without having kF as a free parameter. We run this on the fiducial sim to fix kF to the true value
#
# First we look at wider priors, looking at sim 15 and sim 30 (the fiducial)

# %%
import numpy as np
import emcee_sampler
from chainconsumer import ChainConsumer

# %%
emcee_sampler.compare_corners([1,2],["Sim 15, narrow IGM prior","Sim 15, wider IGM prior"])
# Out:
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
#  /home/chris/.local/lib/python3.5/site-packages/paramz/parameterized.py:61: RuntimeWarning:Don't forget to initialize by self.initialize_parameter()!
# H0 = 6.7000E+01, Omega_b h^2 = 2.2000E-02, Omega_c h^2 = 1.2000E-01, Omega_k = -5.5511E-17, Omega_nu h^2 = 0.0000E+00, A_s = 1.7654E-09, n_s = 9.6590E-01, alpha_s = 0.0000E+00
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# H0 = 6.7000E+01, Omega_b h^2 = 2.2000E-02, Omega_c h^2 = 1.2000E-01, Omega_k = -5.5511E-17, Omega_nu h^2 = 0.0000E+00, A_s = 1.7654E-09, n_s = 9.6590E-01, alpha_s = 0.0000E+00
# WARNING:chainconsumer:Parameter $ln(\tau_0)$ in chain Sim 15, narrow IGM prior is not constrained
# WARNING:chainconsumer:Parameter $ln(\sigma^T_1)$ in chain Sim 15, narrow IGM prior is not constrained
# ...

# %%
emcee_sampler.compare_corners([3,4],["Sim 30, narrow IGM prior","Sim 30, wider IGM prior"])
# Out:
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
#  /home/chris/.local/lib/python3.5/site-packages/paramz/parameterized.py:61: RuntimeWarning:Don't forget to initialize by self.initialize_parameter()!
# H0 = 6.7000E+01, Omega_b h^2 = 2.2000E-02, Omega_c h^2 = 1.2000E-01, Omega_k = -5.5511E-17, Omega_nu h^2 = 0.0000E+00, A_s = 2.0061E-09, n_s = 9.6757E-01, alpha_s = 0.0000E+00
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# H0 = 6.7000E+01, Omega_b h^2 = 2.2000E-02, Omega_c h^2 = 1.2000E-01, Omega_k = -5.5511E-17, Omega_nu h^2 = 0.0000E+00, A_s = 2.0061E-09, n_s = 9.6757E-01, alpha_s = 0.0000E+00
# WARNING:chainconsumer:Parameter $ln(\sigma^T_0)$ in chain Sim 30, narrow IGM prior is not constrained
# WARNING:chainconsumer:Parameter $ln(\gamma_1)$ in chain Sim 30, narrow IGM prior is not constrained

# %%
emcee_sampler.compare_corners([3,5],["Sim 30, with kF","Sim 30, without kF"])
# Out:
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# H0 = 6.7000E+01, Omega_b h^2 = 2.2000E-02, Omega_c h^2 = 1.2000E-01, Omega_k = -5.5511E-17, Omega_nu h^2 = 0.0000E+00, A_s = 2.0061E-09, n_s = 9.6757E-01, alpha_s = 0.0000E+00
# INFO:GP:initializing Y
# INFO:GP:initializing inference method
# INFO:GP:adding kernel and likelihood as parameters
# H0 = 6.7000E+01, Omega_b h^2 = 2.2000E-02, Omega_c h^2 = 1.2000E-01, Omega_k = -5.5511E-17, Omega_nu h^2 = 0.0000E+00, A_s = 2.0061E-09, n_s = 9.6757E-01, alpha_s = 0.0000E+00
# WARNING:chainconsumer:Parameter $ln(\sigma^T_0)$ in chain Sim 30, with kF is not constrained
# WARNING:chainconsumer:Parameter $ln(\gamma_1)$ in chain Sim 30, with kF is not constrained
# WARNING:chainconsumer:Parameter $ln(\gamma_1)$ in chain Sim 30, without kF is not constrained
