# %% [markdown]
# # Compute KDE from MCMC chains

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
from lace_manager.sampler import emcee_sampler
from lace_manager.likelihood import marg_p1d_like

# %% [markdown]
# ### Load a single sampler, and plot posteriors

# %%
rootdir='/Users/font/Projects/LaCE_manager/lace_manager/sampler/chains/'
subfolder=None

# %%
sampler=emcee_sampler.EmceeSampler(read_chain_file=6,
                                subfolder=subfolder,rootdir=rootdir,
                                train_when_reading=True,
                                verbose=True)
# Out:
# will read chain from file 6
# Building archive
# Setting up emulator
# Loading emulator using a specific archive, not the one set in basedir
# Rescaled params to unity volume
# Training GP on 330 points
#  /Users/font/opt/anaconda3/envs/lace_env/lib/python3.8/site-packages/paramz/parameterized.py:61: RuntimeWarning:Don't forget to initialize by self.initialize_parameter()!
# GPs optimised in 0.22 seconds
# H0 = 6.7000E+01, Omega_b h^2 = 2.2000E-02, Omega_c h^2 = 1.2000E-01, Omega_k = -5.5511E-17, Omega_nu h^2 = 0.0000E+00, A_s = 2.0061E-09, n_s = 9.6757E-01, alpha_s = 0.0000E+00
# Setting up likelihood
# Load sampler data

# %%
#plot_params=['$A_s$','$n_s$','$\Delta^2_\star$','$n_\star$']
plot_params=['$\Delta^2_\star$','$n_\star$']
sampler.plot_corner(delta_lnprob_cut=50,plot_params=plot_params)
# Out:
# will keep 26414 \ 27400 points from chain

# %%
sampler.write_kde()
# Out:
# will print KDE to /Users/font/Projects/LaCE_manager/lace_manager/sampler/chains//chain_6/kde.npz
# will keep 26414 \ 27400 points from chain
# 0.293 < Delta2_star < 0.452
# -2.316 < n_star < -2.276
# Delta2_star (max like) = 0.346
# n_star (max like) = -2.299

# %%
kde_fname='{}/kde.npz'.format(sampler.save_directory)
kde_marg_p1d=marg_p1d_like.MargP1DLike(kde_fname=kde_fname)
kde_marg_p1d.plot_log_like()
# Out:
# will setup marg_p1d from KDE file /Users/font/Projects/LaCE_manager/lace_manager/sampler/chains//chain_6/kde.npz

# %% [markdown]
# # KDE from Gaussian

# %%
gauss_marg_p1d=marg_p1d_like.MargP1DLike(sim_label=sampler.like.data.sim_label,
                                        reduced_IGM=True,polyfit=sampler.like.data.polyfit)
gauss_marg_p1d.plot_log_like()
# Out:
# will setup Gaussian marg_p1d

# %%
def write_kde_from_Gauss(gauss_marg_p1d,fname='test_gauss_kde.npz',Nsigmas=4,Nbins=40):
    # figure out Gaussian mean and rms
    mean_x,mean_y=gauss_marg_p1d.Gauss_mean
    Gauss_cov=np.linalg.inv(gauss_marg_p1d.Gauss_icov)
    rms_x,rms_y=np.sqrt(Gauss_cov.diagonal())
    xmin = mean_x - Nsigmas*rms_x
    xmax = mean_x + Nsigmas*rms_x
    ymin = mean_y - Nsigmas*rms_y
    ymax = mean_y + Nsigmas*rms_y
    print('{:.3f} < Delta2_star < {:.3f}'.format(xmin,xmax))
    print('{:.3f} < n_star < {:.3f}'.format(ymin,ymax))
    # setup regular 2D grid for KDE
    Nj=complex(0,Nbins)
    X, Y = np.mgrid[xmin:xmax:Nj, ymin:ymax:Nj]
    Z = np.empty_like(X)
    for ix in range(Nbins):
        for iy in range(Nbins):
            log_like = gauss_marg_p1d.get_log_like(Delta2_star=X[ix,iy],n_star=Y[ix,iy])
            # Z here should be density (likelihood)
            Z[ix,iy] = np.exp(log_like)
    np.savez(fname,D2_star=np.unique(X),n_star=np.unique(Y),density=Z)

# %%
write_kde_from_Gauss(gauss_marg_p1d,Nsigmas=4,Nbins=40)
# Out:
# 0.311 < Delta2_star < 0.381
# -2.313 < n_star < -2.284

# %%
gauss_kde_marg_p1d=marg_p1d_like.MargP1DLike(kde_fname='test_gauss_kde.npz')
gauss_kde_marg_p1d.plot_log_like()
# Out:
# will setup marg_p1d from KDE file test_gauss_kde.npz

# %% [markdown]
# ### Extract actual chain

# %%
from chainconsumer import ChainConsumer

# %%
params_plot, strings_plot=sampler.get_all_params(delta_lnprob_cut=50)
# Out:
# will keep 26414 \ 27400 points from chain

# %%
c=ChainConsumer()
c.add_chain(params_plot,parameters=strings_plot,name="Chains")
c.configure(diagonal_tick_labels=False, tick_font_size=10,kde=1.0,
                    label_font_size=10, max_ticks=4,usetex=False, serif=False)
fig = c.plotter.plot(parameters=plot_params,truth=sampler.truth)

# %%
# make sure you are reading Delta2_star and n_star correctly
D2_star_label=strings_plot[3]
n_star_label=strings_plot[4]
print(D2_star_label,n_star_label)
# Out:
# $\Delta^2_\star$ $n_\star$

# %%
m1,m2=params_plot[:,3:5].transpose().copy()
xmin = m1.min()
xmax = m1.max()
ymin = m2.min()
ymax = m2.max()
print('{:.3f} < {} < {:.3f}'.format(xmin,D2_star_label,xmax))
print('{:.3f} < {} < {:.3f}'.format(ymin,n_star_label,ymax))
# Out:
# 0.293 < $\Delta^2_\star$ < 0.452
# -2.316 < $n_\star$ < -2.276

# %%
mean_D2_star=np.mean(m1)
mean_n_star=np.mean(m2)
print('Delta2_star (mean) =',mean_D2_star)
print('n_star (mean) =',mean_n_star)
# Out:
# Delta2_star (mean) = 0.34547663139245033
# n_star (mean) = -2.2988117365772824

# %% [markdown]
# ### Setup KDE for 2D posterior

# %%
X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([m1, m2])
kernel = stats.gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)

# %%
# best-fit values from KDE
kde_max_D2_star=X[Z==np.max(Z)][0]
kde_max_n_star=Y[Z==np.max(Z)][0]
print('Delta2_star (KDE) =',kde_max_D2_star)
print('n_star (KDE) =',kde_max_n_star)
# Out:
# Delta2_star (KDE) = 0.3445045142733838
# n_star (KDE) = -2.2991540225013236

# %%
plt.figure(figsize=[16,8])
plt.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax],label='density')
plt.plot(m1, m2, 'k.', markersize=0.1)
plt.plot(kde_max_D2_star,kde_max_n_star, 'o', markersize=10,label='max KDE')
plt.plot(mean_D2_star,mean_n_star, 'x', markersize=10,label='mean MCMC')
plt.xlim([xmin, xmax])
plt.ylim([ymin, ymax])
plt.xlabel(r'$\Delta_\star$')
plt.ylabel(r'$n_\star$')
plt.legend()
plt.colorbar()

# %% [markdown]
# ### Further testing

# %%
chain,lnprob,blobs=sampler.get_chain(cube=False,delta_lnprob_cut=50)
# Out:
# will keep 26414 \ 27400 points from chain

# %%
x=blobs['Delta2_star']
y=blobs['n_star']
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()
print('{:.3f} < Delta2_star < {:.3f}'.format(xmin,xmax))
print('{:.3f} < n_star < {:.3f}'.format(ymin,ymax))
# Out:
# 0.293 < Delta2_star < 0.452
# -2.316 < n_star < -2.276

# %%
mean_D2_star=np.mean(x)
mean_n_star=np.mean(y)
print('Delta2_star (mean) =',mean_D2_star)
print('n_star (mean) =',mean_n_star)
# Out:
# Delta2_star (mean) = 0.34547663139245033
# n_star (mean) = -2.2988117365772824

# %%
max_lnprob=np.max(lnprob)
imax=np.where(lnprob==max_lnprob)
max_like_D2_star=x[imax][0]
max_like_n_star=y[imax][0]
print('Delta2_star (max like) =',max_like_D2_star)
print('n_star (max like) =',max_like_n_star)
# Out:
# Delta2_star (max like) = 0.3458245588876878
# n_star (max like) = -2.298673903707106

# %%
X, Y = np.mgrid[xmin:xmax:100j, ymin:ymax:100j]
positions = np.vstack([X.ravel(), Y.ravel()])
values = np.vstack([x, y])
kernel = stats.gaussian_kde(values)
Z = np.reshape(kernel(positions).T, X.shape)

# %%
# best-fit values from KDE
kde_max_D2_star=X[Z==np.max(Z)][0]
kde_max_n_star=Y[Z==np.max(Z)][0]
print('Delta2_star (KDE) =',kde_max_D2_star)
print('n_star (KDE) =',kde_max_n_star)
# Out:
# Delta2_star (KDE) = 0.3445045142733838
# n_star (KDE) = -2.2991540225013236

# %%
plt.figure(figsize=[16,8])
plt.imshow(np.rot90(Z), cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax],label='density')
plt.plot(x, y, 'k.', markersize=0.1)
plt.plot(kde_max_D2_star,kde_max_n_star,'o',markersize=10,label='max KDE')
plt.plot(max_like_D2_star,max_like_n_star,'x',markersize=10,label='max like')
plt.plot(mean_D2_star,mean_n_star,'*',markersize=10,label='mean MCMC')
plt.xlim([xmin, xmax])
plt.ylim([ymin, ymax])
plt.xlabel(r'$\Delta_\star$',fontsize=16)
plt.ylabel(r'$n_\star$',fontsize=16)
plt.legend(fontsize=14)
plt.colorbar()

# %%
Z.shape
# Out:
# (100, 100)

# %%
true_D2_star=sampler.truth['$\\Delta^2_\\star$']
true_n_star=sampler.truth['$n_\\star$']
print(true_D2_star,true_n_star)
# Out:
# 0.34654544748011135 -2.2970382760358423

# %%
newZ=np.copy(Z)
newX=np.copy(X)
newY=np.copy(Y)

# %%
import scipy
test=scipy.interpolate.RectBivariateSpline(np.unique(newX),np.unique(newY),newZ)

# %%
test(np.mean(newX),np.mean(newY))
# Out:
# array([[1.01246493]])

# %%
test.ev(0.35,-2.3)
# Out:
# array(3106.01624349)

# %%
x,y=test.get_knots()

# %%
len(np.unique(x))
# Out:
# 98

# %%
len(x)
# Out:
# 104

# %%
x[:5]
# Out:
# array([0.293174  , 0.293174  , 0.293174  , 0.293174  , 0.29638216])

# %%
x[-5:]
# Out:
# array([0.44876962, 0.45197778, 0.45197778, 0.45197778, 0.45197778])

# %%
np.max(x)
# Out:
# 0.45197777701225367

# %%
np.min(x)
# Out:
# 0.2931740007264609

# %%
np.infty
# Out:
# inf

# %%
X2, Y2 = np.mgrid[xmin:xmax:50j, ymin:ymax:50j]
Z2=test.ev(X2,Y2)

# %%
plt.figure(figsize=[16,8])
plt.imshow(np.rot90(Z2), cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax],label='density')
plt.plot(x, y, 'k.', markersize=0.1)
plt.plot(kde_max_D2_star,kde_max_n_star,'o',markersize=10,label='max KDE')
plt.plot(max_like_D2_star,max_like_n_star,'x',markersize=10,label='max like')
plt.plot(mean_D2_star,mean_n_star,'*',markersize=10,label='mean MCMC')
plt.xlim([xmin, xmax])
plt.ylim([ymin, ymax])
plt.xlabel(r'$\Delta_\star$',fontsize=16)
plt.ylabel(r'$n_\star$',fontsize=16)
plt.legend(fontsize=14)
plt.colorbar()

# %%
def write_KDE(sampler,fname,Nj=100j,delta_lnprob_cut=100,bw_method=None):
    # get chain points and probabilities
    chain,lnprob,blobs=sampler.get_chain(cube=False,delta_lnprob_cut=delta_lnprob_cut)
    # read compressed parameters and set range
    x=blobs['Delta2_star']
    y=blobs['n_star']
    xmin = x.min()
    xmax = x.max()
    ymin = y.min()
    ymax = y.max()
    print('{:.3f} < Delta2_star < {:.3f}'.format(xmin,xmax))
    print('{:.3f} < n_star < {:.3f}'.format(ymin,ymax))
    # maximum likelihood points
    max_lnprob=np.max(lnprob)
    print('max lnprob',max_lnprob)
    imax=np.where(lnprob==max_lnprob)
    max_like_D2_star=x[imax][0]
    max_like_n_star=y[imax][0]
    print('Delta2_star (max like) =',max_like_D2_star)
    print('n_star (max like) =',max_like_n_star)
    # setup regular 2D grid for KDE
    X, Y = np.mgrid[xmin:xmax:Nj, ymin:ymax:Nj]
    positions = np.vstack([X.ravel(), Y.ravel()])
    values = np.vstack([x, y])
    kernel = stats.gaussian_kde(values,bw_method=bw_method)
    Z = np.reshape(kernel(positions).T, X.shape)
    # max-like values from KDE
    kde_max_D2_star=X[Z==np.max(Z)][0]
    kde_max_n_star=Y[Z==np.max(Z)][0]
    print('Delta2_star (max KDE) =',kde_max_D2_star)
    print('n_star (max KDE) =',kde_max_n_star)
    # store to file
    np.savez('{}.npz'.format(fname), Delta2_star=np.unique(X),
             n_star=np.unique(Y), counts_kde=Z)

# %%
def read_KDE(fname):
    data = np.load('{}.npz'.format(fname))
    Delta2_star=data['Delta2_star']
    n_star=data['n_star']
    counts=data['counts_kde']
    return Delta2_star, n_star, counts

# %%
write_KDE(sampler,fname='test_kde',Nj=100j,delta_lnprob_cut=50,bw_method=None)
# Out:
# will keep 26414 \ 27400 points from chain
# 0.293 < Delta2_star < 0.452
# -2.316 < n_star < -2.276
# max lnprob 178.32144836886184
# Delta2_star (max like) = 0.3458245588876878
# n_star (max like) = -2.298673903707106
# Delta2_star (max KDE) = 0.3445045142733838
# n_star (max KDE) = -2.2991540225013236

# %%
Delta2_star, n_star, counts = read_KDE('test_kde')

# %%
max_counts=np.max(counts)
plt.figure(figsize=[16,8])
plt.imshow(np.rot90(counts/max_counts), cmap=plt.cm.gist_earth_r,
           extent=[np.min(Delta2_star),np.max(Delta2_star),
                   np.min(n_star),np.max(n_star)])
plt.xlabel(r'$\Delta_\star$',fontsize=16)
plt.ylabel(r'$n_\star$',fontsize=16)
plt.colorbar()
plt.title('normalised counts')
# Out:
# Text(0.5, 1.0, 'normalised counts')

# %% [markdown]
# # Use new KDE object

# %%
from lace_manager.likelihood import marg_p1d_like

# %%
sampler.write_kde(delta_lnprob_cut=25,Nj=20j)
# Out:
# will print KDE to /Users/font/Projects/LaCE_manager/lace_manager/sampler/chains//chain_6/kde.npz
# will keep 26337 \ 27400 points from chain
# 0.308 < Delta2_star < 0.389
# -2.313 < n_star < -2.279
# Delta2_star (max like) = 0.3458245588876878
# n_star (max like) = -2.298673903707106
# Delta2_star (max KDE) = 0.34668023982980517
# n_star (max KDE) = -2.297322090611341
# x size (20, 20) 20
# y size (20, 20) 20
# z size (20, 20)

# %%
kde_fname='/Users/font/Projects/LaCE_manager/lace_manager/sampler/chains/chain_6/kde.npz'
#kde_fname='/Users/font/Projects/LaCE_manager/notebooks/example_kde.npz'
marg_p1d=marg_p1d_like.MargP1DLike(kde_fname=kde_fname)
# Out:
# will setup marg_p1d from KDE file /Users/font/Projects/LaCE_manager/lace_manager/sampler/chains/chain_6/kde.npz
# read KDE from file /Users/font/Projects/LaCE_manager/lace_manager/sampler/chains/chain_6/kde.npz
# will divide by max prob = 7274.357697742956

# %%
marg_p1d.plot_log_like(min_Delta2_star=0.31,max_Delta2_star=0.38)

# %%
x,y=marg_p1d.kde_prob.get_knots()
xmin = x.min()
xmax = x.max()
ymin = y.min()
ymax = y.max()
print('{:.3f} < Delta2_star < {:.3f}'.format(xmin,xmax))
print('{:.3f} < n_star < {:.3f}'.format(ymin,ymax))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 x,y=marg_p1d.kde_prob.get_knots()
#       2 xmin = x.min()
#       3 xmax = x.max()
#
# NameError: name 'marg_p1d' is not defined

# %%
data = np.load(kde_fname)
Delta2_star=data['D2_star']
n_star=data['n_star']
density=data['density']
max_prob=np.max(density)
print('max probability',max_prob)
lnprob=np.log(density)
max_lnprob=np.max(lnprob)
print('max lnprob',max_lnprob)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 data = np.load(kde_fname)
#       2 Delta2_star=data['D2_star']
#       3 n_star=data['n_star']
#
# NameError: name 'np' is not defined

# %%
plt.figure(figsize=[16,3])
plt.imshow(np.rot90(density), cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax],label='density')
plt.xlabel(r'$\Delta_\star$',fontsize=16)
plt.ylabel(r'$n_\star$',fontsize=16)
plt.colorbar()

# %%
plt.figure(figsize=[16,3])
plt.imshow(np.exp(np.rot90(lnprob-max_lnprob)),
           cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax],label='density')
plt.xlabel(r'$\Delta_\star$',fontsize=16)
plt.ylabel(r'$n_\star$',fontsize=16)
plt.colorbar()

# %%
import scipy.interpolate

# %%
test_A=scipy.interpolate.RectBivariateSpline(Delta2_star,n_star,density)
test_A.ev(np.mean(Delta2_star),np.mean(n_star))
# Out:
# array(1.01246493)

# %%
xmin=np.min(Delta2_star)
xmax=np.max(Delta2_star)
ymin=np.min(n_star)
ymax=np.max(n_star)
X, Y = np.mgrid[xmin:xmax:200j, ymin:ymax:200j]
Z=marg_p1d.kde_prob.ev(X,Y)

# %%
plt.figure(figsize=[16,3])
plt.imshow(np.rot90(Z),
           cmap=plt.cm.gist_earth_r,extent=[xmin, xmax, ymin, ymax],label='density')
plt.xlabel(r'$\Delta_\star$',fontsize=16)
plt.ylabel(r'$n_\star$',fontsize=16)
plt.colorbar()

# %%
bin_edges=[-2.34403236 -2.34227869 -2.34052503 -2.33877136 -2.33701769 -2.33526403
 -2.33351036 -2.3317567  -2.33000303 -2.32824937 -2.3264957  -2.32474204
 -2.32298837 -2.3212347  -2.31948104 -2.31772737 -2.31597371 -2.31422004
 -2.31246638 -2.31071271 -2.30895904 -2.30720538 -2.30545171 -2.30369805
 -2.30194438 -2.30019072 -2.29843705 -2.29668339 -2.29492972 -2.29317605
 -2.29142239 -2.28966872 -2.28791506 -2.28616139 -2.28440773 -2.28265406
 -2.28090039 -2.27914673 -2.27739306 -2.2756394  -2.27388573 -2.27213207
 -2.2703784  -2.26862473 -2.26687107 -2.2651174  -2.26336374 -2.26161007
 -2.25985641 -2.25810274 -2.25634908]
bin_counts=[2.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.5000e+01
 0.0000e+00 4.0000e+00 0.0000e+00 1.0000e+00 5.2000e+01 6.9000e+01
 2.4500e+02 7.1500e+02 1.9860e+03 3.9420e+03 8.1480e+03 1.3254e+04
 2.1257e+04 2.8661e+04 3.6903e+04 4.0650e+04 4.2775e+04 3.9044e+04
 3.5029e+04 3.0005e+04 2.4566e+04 2.0821e+04 1.7639e+04 1.5135e+04
 1.3060e+04 1.1161e+04 8.8360e+03 6.8660e+03 5.4570e+03 4.7640e+03
 3.8480e+03 3.2760e+03 2.6910e+03 1.9420e+03 1.5910e+03 1.4370e+03
 9.4400e+02 7.2300e+02 3.9800e+02 2.0400e+02 1.0500e+02 1.1000e+02
 1.8000e+01 5.0000e+00]
# Out:
#   Input In [50]
#     bin_counts=[2.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 0.0000e+00 1.5000e+01
#                            ^
# SyntaxError: invalid syntax

# %%
bin_edges=np.array([-2.34403236, -2.34227869, -2.34052503, -2.33877136, -2.33701769,
       -2.33526403, -2.33351036, -2.3317567 , -2.33000303, -2.32824937,
       -2.3264957 , -2.32474204, -2.32298837, -2.3212347 , -2.31948104,
       -2.31772737, -2.31597371, -2.31422004, -2.31246638, -2.31071271,
       -2.30895904, -2.30720538, -2.30545171, -2.30369805, -2.30194438,
       -2.30019072, -2.29843705, -2.29668339, -2.29492972, -2.29317605,
       -2.29142239, -2.28966872, -2.28791506, -2.28616139, -2.28440773,
       -2.28265406, -2.28090039, -2.27914673, -2.27739306, -2.2756394 ,
       -2.27388573, -2.27213207, -2.2703784 , -2.26862473, -2.26687107,
       -2.2651174 , -2.26336374, -2.26161007, -2.25985641, -2.25810274,
       -2.25634908])

# %%
bin_edges.shape
# Out:
# (51,)

# %%
bin_counts=np.array([2.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
       1.5000e+01, 0.0000e+00, 4.0000e+00, 0.0000e+00, 1.0000e+00,
       5.2000e+01, 6.9000e+01, 2.4500e+02, 7.1500e+02, 1.9860e+03,
       3.9420e+03, 8.1480e+03, 1.3254e+04, 2.1257e+04, 2.8661e+04,
       3.6903e+04, 4.0650e+04, 4.2775e+04, 3.9044e+04, 3.5029e+04,
       3.0005e+04, 2.4566e+04, 2.0821e+04, 1.7639e+04, 1.5135e+04,
       1.3060e+04, 1.1161e+04, 8.8360e+03, 6.8660e+03, 5.4570e+03,
       4.7640e+03, 3.8480e+03, 3.2760e+03, 2.6910e+03, 1.9420e+03,
       1.5910e+03, 1.4370e+03, 9.4400e+02, 7.2300e+02, 3.9800e+02,
       2.0400e+02, 1.0500e+02, 1.1000e+02, 1.8000e+01, 5.0000e+00])

# %%
bin_counts.shape
# Out:
# (50,)
