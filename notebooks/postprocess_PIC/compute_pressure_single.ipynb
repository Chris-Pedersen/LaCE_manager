# %% [markdown]
# # Compute pressure smoothing scale from GenPK outputs

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 120
mpl.rcParams['figure.dpi'] = 120
import os
import json
# our modules below
from lace.postprocess import filtering_length

# %%
# directory with raw simulation outputs
raw_dir='/data/desi/common/HydroData/Emulator/sims_256/'
# directory with simulation post-procesings
post_dir='/data/desi/common/HydroData/Emulator/test_256/'
# label identifying simulation
sim_tag='sim_pair_1/sim_minus/'
kmax_Mpc = 15

# %%
filtering_length.fit_filtering_length(raw_dir+sim_tag,post_dir+sim_tag,
                        kmax_Mpc=kmax_Mpc,write_json=True,
                        show_plots=True,verbose=True)
# Out:
# read GADGET config file /data/desi/common/HydroData/Emulator/sims_256/sim_pair_1/sim_minus//paramfile.gadget
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_000
# successfully read snapshot using fork from Simeon
# A = 1.115885e-04 ; n = 8.392253e-01 ; k_F = 13.1245 1/Mpc
# Paramater covariance = [[ 7.85696590e-12 -4.93201344e-08  4.21889335e-07]
#  [-4.93201344e-08  3.37895383e-04 -3.31486669e-03]
#  [ 4.21889335e-07 -3.31486669e-03  4.23992841e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_001
# successfully read snapshot using fork from Simeon
# A = 1.053480e-04 ; n = 8.537135e-01 ; k_F = 12.7143 1/Mpc
# Paramater covariance = [[ 7.42136644e-12 -4.95324640e-08  3.89732310e-07]
#  [-4.95324640e-08  3.60680197e-04 -3.25405114e-03]
#  [ 3.89732310e-07 -3.25405114e-03  3.83308327e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_002
# successfully read snapshot using fork from Simeon
# A = 1.013292e-04 ; n = 8.726269e-01 ; k_F = 12.2439 1/Mpc
# Paramater covariance = [[ 7.28415489e-12 -5.07827829e-08  3.62146649e-07]
#  [-5.07827829e-08  3.86058441e-04 -3.15587004e-03]
#  [ 3.62146649e-07 -3.15587004e-03  3.37362071e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_003
# successfully read snapshot using fork from Simeon
# A = 9.666995e-05 ; n = 8.895411e-01 ; k_F = 11.8063 1/Mpc
# Paramater covariance = [[ 7.11439675e-12 -5.22736525e-08  3.39793548e-07]
#  [-5.22736525e-08  4.18715055e-04 -3.12001428e-03]
#  [ 3.39793548e-07 -3.12001428e-03  3.04613331e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_004
# successfully read snapshot using fork from Simeon
# A = 9.107286e-05 ; n = 8.993201e-01 ; k_F = 11.4602 1/Mpc
# Paramater covariance = [[ 6.64720800e-12 -5.21439246e-08  3.15191598e-07]
#  [-5.21439246e-08  4.46055785e-04 -3.09257097e-03]
#  [ 3.15191598e-07 -3.09257097e-03  2.81600650e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_005
# successfully read snapshot using fork from Simeon
# A = 8.347203e-05 ; n = 9.030026e-01 ; k_F = 11.1860 1/Mpc
# Paramater covariance = [[ 5.72362427e-12 -4.92806151e-08  2.81564952e-07]
#  [-4.92806151e-08  4.63046083e-04 -3.03764209e-03]
#  [ 2.81564952e-07 -3.03764209e-03  2.62422794e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_006
# successfully read snapshot using fork from Simeon
# A = 7.255496e-05 ; n = 8.874448e-01 ; k_F = 10.9526 1/Mpc
# Paramater covariance = [[ 4.41438492e-12 -4.41443280e-08  2.42253856e-07]
#  [-4.41443280e-08  4.83053033e-04 -3.05336078e-03]
#  [ 2.42253856e-07 -3.05336078e-03  2.55572997e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_007
# successfully read snapshot using fork from Simeon
# A = 6.370556e-05 ; n = 8.727881e-01 ; k_F = 10.6520 1/Mpc
# Paramater covariance = [[ 3.41716252e-12 -3.93786773e-08  2.04661482e-07]
#  [-3.93786773e-08  4.98094306e-04 -2.99272461e-03]
#  [ 2.04661482e-07 -2.99272461e-03  2.39637269e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_008
# successfully read snapshot using fork from Simeon
# A = 4.837677e-05 ; n = 8.541520e-01 ; k_F = 9.8197 1/Mpc
# Paramater covariance = [[ 1.90117474e-12 -2.97920963e-08  1.31808367e-07]
#  [-2.97920963e-08  5.16050977e-04 -2.66218430e-03]
#  [ 1.31808367e-07 -2.66218430e-03  1.85676797e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_009
# successfully read snapshot using fork from Simeon
# A = 4.188374e-05 ; n = 8.440749e-01 ; k_F = 9.3587 1/Mpc
# Paramater covariance = [[ 1.47573794e-12 -2.72773021e-08  1.10357421e-07]
#  [-2.72773021e-08  5.59884550e-04 -2.65573686e-03]
#  [ 1.10357421e-07 -2.65573686e-03  1.71637614e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_010
# successfully read snapshot using fork from Simeon
# A = 3.671790e-05 ; n = 8.293095e-01 ; k_F = 8.9203 1/Mpc
# Paramater covariance = [[ 1.23554556e-12 -2.66774318e-08  9.93837397e-08]
#  [-2.66774318e-08  6.43288593e-04 -2.82825958e-03]
#  [ 9.93837397e-08 -2.82825958e-03  1.70747353e-02]]
# genpk already ran /data/desi/common/HydroData/Emulator/test_256/sim_pair_1/sim_minus//genpk//PK-by-PART_011
# successfully read snapshot using fork from Simeon
# A = 3.279142e-05 ; n = 8.174608e-01 ; k_F = 8.4665 1/Mpc
# Paramater covariance = [[ 1.12349116e-12 -2.79041361e-08  9.53230593e-08]
#  [-2.79041361e-08  7.78874701e-04 -3.16221789e-03]
#  [ 9.53230593e-08 -3.16221789e-03  1.77438420e-02]]
