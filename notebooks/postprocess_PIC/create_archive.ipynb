# %% [markdown]
# # Collect P1D files and create light-weight archive

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import shutil
import os
import json

# %%
def copy_file_if_needed(in_dir,out_dir,fname):
    in_fname = os.path.join(in_dir,fname)
    out_fname = os.path.join(out_dir,fname)
    if os.path.exists(out_fname):
        print('file {} already exists'.format(out_fname))
        return
    else:
        print('copy file {} to {}'.format(in_fname,out_fname))
        shutil.copyfile(in_fname,out_fname)
        return

# %%
def copy_dir_if_needed(in_dir,out_dir,dirname):
    in_dirname = os.path.join(in_dir,dirname)
    out_dirname = os.path.join(out_dir,dirname)
    
    if os.path.exists(out_dirname):
        if not os.path.isdir(out_dirname):
            raise ValueError(out_dirname+' exists but is not a folder!')
        print('folder {} already exists'.format(out_dirname))
        return
    else:
        print('copy folder {} to {}'.format(in_dirname,out_dirname))
        shutil.copytree(in_dirname,out_dirname)
        return

# %%
def mkdir_if_needed(dirname):
    if os.path.exists(dirname):
        print('folder {} already exists'.format(dirname))
        if not os.path.isdir(dirname):
            raise ValueError(dirname+' exists but is not a folder!')
    else:
        print('create directory',dirname)
        os.mkdir(dirname)

# %%
def assert_dir_exists(dirname):
    if not os.path.isdir(dirname):
        raise ValueError(dirname+' folder does not exist!')

# %%
pos_base_dir='/data/desi/common/HydroData/Emulator/postprocess/Australia20'

# %%
arc_base_dir=os.environ['LYA_EMU_REPO']+'/lace/emulator/sim_suites/test_archive_30'
mkdir_if_needed(arc_base_dir)
# Out:
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30 already exists

# %%
copy_file_if_needed(pos_base_dir,arc_base_dir,'latin_hypercube.json')
with open(arc_base_dir+'/latin_hypercube.json') as json_file:
    LH_data = json.load(json_file)
nsamples=LH_data['nsamples']
print('nsamples =',nsamples)
# Out:
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/latin_hypercube.json already exists
# nsamples = 30

# %%
for sample in range(nsamples):
    sim_pair='sim_pair_{}'.format(sample)
    pos_pair_dir = os.path.join(pos_base_dir,sim_pair)
    arc_pair_dir = os.path.join(arc_base_dir,sim_pair)

    assert_dir_exists(pos_pair_dir)
    mkdir_if_needed(arc_pair_dir)
    copy_file_if_needed(pos_pair_dir,arc_pair_dir,'parameter.json')
    for sim in ['sim_minus','sim_plus']:
        pos_dir = os.path.join(pos_pair_dir, sim)        
        arc_dir = os.path.join(arc_pair_dir, sim)
        assert_dir_exists(pos_dir)
        mkdir_if_needed(arc_dir)
        for fname in ['paramfile.gadget','paramfile.genic']:
            copy_file_if_needed(pos_dir,arc_dir,fname)
        for snap in range(11):
            p1d_fname='p1d_{}_Ns500_wM0.05.json'.format(snap)
            copy_file_if_needed(pos_dir,arc_dir,p1d_fname)
# Out:
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_0/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_1/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_2/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_3/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_4/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_5/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_6/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_7/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_8/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_9/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_10/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_11 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_11/parameter.json already exists
# ...
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_26/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_27/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_28/sim_plus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29 already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/parameter.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_minus/p1d_10_Ns500_wM0.05.json already exists
# folder /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/paramfile.gadget already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/paramfile.genic already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_0_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_1_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_2_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_3_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_4_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_5_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_6_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_7_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_8_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_9_Ns500_wM0.05.json already exists
# file /nfs/pic.es/user/a/afontrib/Projects/LaCE//lace/emulator/sim_suites/test_archive_30/sim_pair_29/sim_plus/p1d_10_Ns500_wM0.05.json already exists
