# %% [markdown]
# # Compare P1D stored in different archives

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys
import os
import json
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rcParams['savefig.dpi'] = 120
mpl.rcParams['figure.dpi'] = 120
import p1d_arxiv

# %% [markdown]
# ### Specify suite of simulations to use and read metadata

# %%
old_arxiv=p1d_arxiv.ArxivP1D(None,skewers_label='Ns100_wM0.05',drop_tau_rescalings=True,drop_temp_rescalings=True,
                             undersample_z=3)
new_arxiv=p1d_arxiv.ArxivP1D(None,skewers_label='Ns100_wM0.07',drop_tau_rescalings=True,drop_temp_rescalings=True,
                             undersample_z=3)
N=len(old_arxiv.data)
assert N==len(new_arxiv.data),'size mismatch'
# figure out number of redshifts
nmodels=old_arxiv.nsamples
Nz=int(N/nmodels)
print('Nz=',Nz)
# Out:
# Nz= 4

# %%
for i in range(Nz):
    old_data=old_arxiv.data[i]
    new_data=new_arxiv.data[i]
    plt.semilogx(old_data['k_Mpc'],old_data['k_Mpc']*old_data['p1d_Mpc'],label='old')
    plt.semilogx(new_data['k_Mpc'],new_data['k_Mpc']*new_data['p1d_Mpc'],label='new')
    plt.xlabel('k [1/Mpc]')
    plt.ylabel('k * P1D')
    plt.title('z = %s'%old_data['z'])
    plt.legend()
    plt.show()
